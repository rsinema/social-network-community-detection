# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pathlib import Path
file_path = Path("../data/project_3_graph.graphml")

# %%
G = nx.read_graphml(file_path)

# %%
# TODO visualize the graph here
